# %%
# %load_ext autoreload
# %autoreload 2

# Setup Environment
import sys
import os
ROOT = '../../'
sys.path.append(ROOT)

import gym
from gym.spaces import Discrete
import numpy as np
from gym.wrappers.monitoring.video_recorder import VideoRecorder
from IPython.display import HTML
from source.agents.dqn_agent import DQNAgent
from source.utils import utils
from tqdm import tqdm
import torch
import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# using device: cpu
# dqn_agent test passed!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Policy Eval
# Params
num_epoch = 100
num_episode = 10
video_path = os.path.join(ROOT, "video/dqn_lunar.mp4")
random_seed = 101

# Initialize
history = []
total_reward = 0
# set random seeds
rng = np.random.default_rng(random_seed)
#random.seed(random_seed)
np.random.seed(random_seed)
#torch.manual_seed(random_seed)
# epsilon decay
epsilon_schedule = utils.create_decay_schedule(num_epoch)
lr_schedule = utils.create_decay_schedule(num_epoch)

# Create Environment.
#env = gym.make('Taxi-v3')
# using render_mode=rgb_array so that video recording works
env = gym.make(
    "LunarLander-v2",
    render_mode='rgb_array'
)
#env = gym.make("CarRacing-v2", render_mode='rgb_array', continuous=False)
#env = gym.make("CartPole-v1", render_mode='rgb_array')
env.np_random = rng

# Create Agent
agent = DQNAgent(
    state_space=env.observation_space,
    action_space=env.action_space,
    discount_rate=0.99,
    epsilon=0.9, # this is the staring value of epsilon decay
    learning_rate=1e-3,
    learning=True,
    batch_size = 128,
    tau = 0.005,
    eps_decay=3000,
    net_params={'width': 128, 'n_hidden':2},
    update_freq=500
)
# Start Learning
for i in range(num_epoch):
    hisotry = []
    success = 0
    for _ in tqdm(range(num_episode)):
        reward, steps = agent.play_episode(env)#,epsilon=epsilon_schedule[i])
        if reward > 0:
            success += 1
        history.append(reward)
        total_reward += reward
    #score = agent.update()
    print(
        f"step: {i}, epsilon: {agent._epsilon}, average_return: {np.mean(history)}, success rate: {success / num_episode}")
print(f"\nrewarding episodes: {total_reward}")

# For off policy learning only: get greedy policy (no exploration)
#agent._policy = get_epsilon_greedy_policy_from_action_values(agent._Q.weight)
# Run Eval
avarge_return, success_rate = utils.evaluate_agent(agent, env, 100)
print(f"Average return = {avarge_return}, Success rate = {success_rate}")

# play last episode with video recording

utils.plot_history(history)
# Out:
# using device: cpu
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 0, epsilon: 0.05, average_return: -202.0056594988751, success rate: 0.2
# 100%|██████████| 10/10 [00:10<00:00,  1.04s/it]
# step: 1, epsilon: 0.05, average_return: -105.28518500058001, success rate: 0.4
# 100%|██████████| 10/10 [00:08<00:00,  1.23it/s]
# step: 2, epsilon: 0.05, average_return: -63.06189930344139, success rate: 0.5
# 100%|██████████| 10/10 [00:12<00:00,  1.25s/it]
# step: 3, epsilon: 0.05, average_return: -32.47299006976425, success rate: 0.7
# 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# step: 4, epsilon: 0.05, average_return: 1.6431572963582497, success rate: 0.8
# 100%|██████████| 10/10 [00:15<00:00,  1.54s/it]
# step: 5, epsilon: 0.05, average_return: 18.353512689682223, success rate: 0.8
# 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# step: 6, epsilon: 0.05, average_return: 38.08088723889334, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 7, epsilon: 0.05, average_return: 56.87975342733243, success rate: 0.9
# 100%|██████████| 10/10 [00:15<00:00,  1.50s/it]
# step: 8, epsilon: 0.05, average_return: 58.403480241421825, success rate: 0.5
# 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# step: 9, epsilon: 0.05, average_return: 56.2477406533602, success rate: 0.5
# 100%|██████████| 10/10 [00:15<00:00,  1.59s/it]
# step: 10, epsilon: 0.05, average_return: 49.17907529565722, success rate: 0.5
# 100%|██████████| 10/10 [00:11<00:00,  1.19s/it]
# step: 11, epsilon: 0.05, average_return: 54.23564148291498, success rate: 0.8
# 100%|██████████| 10/10 [00:12<00:00,  1.25s/it]
# step: 12, epsilon: 0.05, average_return: 65.30865049835263, success rate: 1.0
# 100%|██████████| 10/10 [00:12<00:00,  1.22s/it]
# step: 13, epsilon: 0.05, average_return: 75.03808032442348, success rate: 1.0
# 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# step: 14, epsilon: 0.05, average_return: 80.23349092002461, success rate: 0.8
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# step: 15, epsilon: 0.05, average_return: 80.7421473423326, success rate: 0.7
# 100%|██████████| 10/10 [00:10<00:00,  1.06s/it]
# step: 16, epsilon: 0.05, average_return: 88.6409499697179, success rate: 1.0
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# step: 17, epsilon: 0.05, average_return: 95.01284681850672, success rate: 0.9
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# step: 18, epsilon: 0.05, average_return: 99.4670396079235, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# step: 19, epsilon: 0.05, average_return: 101.81214426469926, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.07it/s]
# step: 20, epsilon: 0.05, average_return: 104.16793455489623, success rate: 0.8
# 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# step: 21, epsilon: 0.05, average_return: 106.7443802593607, success rate: 0.8
# 100%|██████████| 10/10 [00:10<00:00,  1.07s/it]
# step: 22, epsilon: 0.05, average_return: 109.58167610805492, success rate: 0.8
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# step: 23, epsilon: 0.05, average_return: 109.6370334763254, success rate: 0.9
# 100%|██████████| 10/10 [00:10<00:00,  1.06s/it]
# step: 24, epsilon: 0.05, average_return: 110.43565907849852, success rate: 0.8
# 100%|██████████| 10/10 [00:16<00:00,  1.64s/it]
# step: 25, epsilon: 0.05, average_return: 110.47855152464105, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# step: 26, epsilon: 0.05, average_return: 110.84609941106876, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 27, epsilon: 0.05, average_return: 112.67132217826172, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# step: 28, epsilon: 0.05, average_return: 113.44022141985067, success rate: 0.7
# 100%|██████████| 10/10 [00:09<00:00,  1.00it/s]
# step: 29, epsilon: 0.05, average_return: 116.3527806644846, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# step: 30, epsilon: 0.05, average_return: 120.76186389228069, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 31, epsilon: 0.05, average_return: 119.40473647044378, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.22it/s]
# step: 32, epsilon: 0.05, average_return: 119.00705306649063, success rate: 0.8
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 33, epsilon: 0.05, average_return: 118.51157975665123, success rate: 0.8
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]
# step: 34, epsilon: 0.05, average_return: 121.33351543146577, success rate: 1.0
# 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# step: 35, epsilon: 0.05, average_return: 123.4913730737638, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.01it/s]
# step: 36, epsilon: 0.05, average_return: 126.50144790499172, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.12it/s]
# step: 37, epsilon: 0.05, average_return: 129.81022900745063, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# step: 38, epsilon: 0.05, average_return: 132.52792487955622, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 39, epsilon: 0.05, average_return: 132.98262270102336, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 40, epsilon: 0.05, average_return: 134.09065799743698, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 41, epsilon: 0.05, average_return: 134.63077493796357, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# step: 42, epsilon: 0.05, average_return: 136.5316554786713, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.24it/s]
# step: 43, epsilon: 0.05, average_return: 137.49618792174778, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.11it/s]
# step: 44, epsilon: 0.05, average_return: 139.8053578563404, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.22it/s]
# step: 45, epsilon: 0.05, average_return: 140.14231492824695, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.23it/s]
# step: 46, epsilon: 0.05, average_return: 140.18051475603326, success rate: 0.8
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# step: 47, epsilon: 0.05, average_return: 141.70319405477068, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# step: 48, epsilon: 0.05, average_return: 142.0949402333798, success rate: 0.8
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# step: 49, epsilon: 0.05, average_return: 144.24856565022154, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 50, epsilon: 0.05, average_return: 146.56107038777776, success rate: 1.0
# 100%|██████████| 10/10 [00:10<00:00,  1.06s/it]
# step: 51, epsilon: 0.05, average_return: 147.97770219039424, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# step: 52, epsilon: 0.05, average_return: 150.2943256774662, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# step: 53, epsilon: 0.05, average_return: 151.18919304786112, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 54, epsilon: 0.05, average_return: 153.29935305555173, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 55, epsilon: 0.05, average_return: 153.206963789922, success rate: 0.9
# 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# step: 56, epsilon: 0.05, average_return: 152.58652439995458, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 57, epsilon: 0.05, average_return: 154.50894168080367, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.14it/s]
# step: 58, epsilon: 0.05, average_return: 156.49628758219362, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]
# step: 59, epsilon: 0.05, average_return: 158.09862399296415, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.08it/s]
# step: 60, epsilon: 0.05, average_return: 157.98186361020183, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# step: 61, epsilon: 0.05, average_return: 158.3053660699512, success rate: 0.8
# 100%|██████████| 10/10 [00:09<00:00,  1.01it/s]
# step: 62, epsilon: 0.05, average_return: 158.44519095951873, success rate: 0.8
# 100%|██████████| 10/10 [00:12<00:00,  1.25s/it]
# step: 63, epsilon: 0.05, average_return: 158.48416623471968, success rate: 0.7
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]
# step: 64, epsilon: 0.05, average_return: 158.9385145655014, success rate: 0.9
# 100%|██████████| 10/10 [00:10<00:00,  1.09s/it]
# step: 65, epsilon: 0.05, average_return: 159.9533121568871, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]
# step: 66, epsilon: 0.05, average_return: 161.195692250664, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.14it/s]
# step: 67, epsilon: 0.05, average_return: 161.8667354218053, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 68, epsilon: 0.05, average_return: 162.83544496422897, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.21it/s]
# step: 69, epsilon: 0.05, average_return: 162.92426649619262, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]
# step: 70, epsilon: 0.05, average_return: 163.3774314314441, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# step: 71, epsilon: 0.05, average_return: 164.46778263120393, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# step: 72, epsilon: 0.05, average_return: 165.72792426030614, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.01it/s]
# step: 73, epsilon: 0.05, average_return: 166.63364544624548, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# step: 74, epsilon: 0.05, average_return: 167.00424810639808, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.12it/s]
# step: 75, epsilon: 0.05, average_return: 166.97773748121804, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 76, epsilon: 0.05, average_return: 167.0867912790307, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# step: 77, epsilon: 0.05, average_return: 167.4270048524492, success rate: 0.8
# 100%|██████████| 10/10 [00:10<00:00,  1.06s/it]
# step: 78, epsilon: 0.05, average_return: 166.44217459345663, success rate: 0.8
# 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# step: 79, epsilon: 0.05, average_return: 166.22018178037447, success rate: 0.7
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 80, epsilon: 0.05, average_return: 166.4406620991301, success rate: 0.7
# 100%|██████████| 10/10 [00:15<00:00,  1.51s/it]
# step: 81, epsilon: 0.05, average_return: 165.90495823930172, success rate: 0.9
# 100%|██████████| 10/10 [00:14<00:00,  1.43s/it]
# step: 82, epsilon: 0.05, average_return: 165.35729397753278, success rate: 0.8
# 100%|██████████| 10/10 [00:12<00:00,  1.23s/it]
# step: 83, epsilon: 0.05, average_return: 165.89526866798974, success rate: 0.9
# 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]
# step: 84, epsilon: 0.05, average_return: 167.0265032994112, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
# step: 85, epsilon: 0.05, average_return: 167.83423393021522, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]
# step: 86, epsilon: 0.05, average_return: 168.86080744842823, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.06it/s]
# step: 87, epsilon: 0.05, average_return: 169.5412367783792, success rate: 1.0
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# step: 88, epsilon: 0.05, average_return: 169.93088377229358, success rate: 1.0
# 100%|██████████| 10/10 [00:10<00:00,  1.02s/it]
# step: 89, epsilon: 0.05, average_return: 170.0573016617745, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 90, epsilon: 0.05, average_return: 170.47777363296356, success rate: 1.0
# 100%|██████████| 10/10 [00:11<00:00,  1.10s/it]
# step: 91, epsilon: 0.05, average_return: 170.78414833975626, success rate: 0.9
# 100%|██████████| 10/10 [00:08<00:00,  1.14it/s]
# step: 92, epsilon: 0.05, average_return: 171.68618042511585, success rate: 1.0
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 93, epsilon: 0.05, average_return: 172.46836080677008, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.11it/s]
# step: 94, epsilon: 0.05, average_return: 173.14091376464515, success rate: 0.9
# 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# step: 95, epsilon: 0.05, average_return: 173.495530418064, success rate: 0.8
# 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# step: 96, epsilon: 0.05, average_return: 174.16032003626765, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# step: 97, epsilon: 0.05, average_return: 174.00531881026805, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.11it/s]
# step: 98, epsilon: 0.05, average_return: 173.85145215285075, success rate: 1.0
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
# step: 99, epsilon: 0.05, average_return: 173.4238573029513, success rate: 1.0
#
# rewarding episodes: 173423.8573029512
# 100%|██████████| 100/100 [00:04<00:00, 23.74it/s]
# Average return = 83.24925991398524, Success rate = 0.95

# %%
from source.agents.dqn_agent import DenseNet, DenseNet1
from torchsummary import summary


net1 = DenseNet(8, 4, 128, 2, False)
summary(net1, (1,8))
net2 = DenseNet1(8, 4)
summary(net2, (1,8))
# Out:
# Failed to start the Kernel.
#
# request to http://localhost:8888/api/sessions?1672591956358 failed, reason: connect ETIMEDOUT 127.0.0.1:8888.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
reward, _ = agent.play_episode(env, video_path=video_path, epsilon=0.0)
print(video_path)
print(reward)
html=utils.render_mp4(video_path)
HTML(html)
# Out:
# Failed to start the Kernel.
#
# request to http://localhost:8888/api/sessions?1672591956358 failed, reason: connect ETIMEDOUT 127.0.0.1:8888.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# Failed to start the Kernel.
#
# request to http://localhost:8888/api/sessions?1672591956358 failed, reason: connect ETIMEDOUT 127.0.0.1:8888.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
